# %% [markdown]
# ### Get the stt_name of all the pdfs files

# %%
import os

def extract_names_from_pdfs(folder_path):
    """
    Extracts a specified part of PDF file names in a given folder and maps them to
    the full file names in a dictionary.

    Parameters:
        folder_path (str): The path to the folder containing the PDF files.

    Returns:
        Dict[str, str]: A dictionary mapping extracted name parts to full file names.
    """
    # Get all file names in the folder
    all_files = os.listdir(folder_path)
    
    # Filter for PDF files
    pdf_files = [f for f in all_files if f.lower().endswith('.pdf')]
    
    # Extract the desired part of the file name and store in a dictionary
    # with the extracted name as the key and the full file name as the value
    extracted_names = {}
    for filename in pdf_files:
        if "_TRAN_" in filename:
            key = filename.split("_TRAN_")[0].lower()
        elif "_LOC_" in filename:
            key = filename.split("_LOC_")[0].lower()
        elif  "_LOCATIONS_" in filename :  
            key = filename.split("_LOCATIONS_")[0].lower() 
        else:
            continue
        extracted_names[key] = filename
    
    return extracted_names

# %% [markdown]
# ### Read the pdf's using pdfplumber

# %%
# Read the  pdf

import pdfplumber

# settings of extract table 
table_settings = {
    "vertical_strategy": "lines",
    "horizontal_strategy": "lines",
    "snap_y_tolerance": 5,
    "intersection_x_tolerance": 15,
}

def extract_tables_from_pdf(pdf_path):
    with pdfplumber.open(pdf_path) as pdf:
        all_tables = []
        for page in pdf.pages:
            tables = page.extract_tables(table_settings)
            for table in tables:
                all_tables.append(table)
        all_tables = [pd.DataFrame(table) for table in all_tables]
                
        all_tables = [x for x in all_tables if (len(x) > 20) & (x.shape[1] > 5 ) ]#& (len(x) < 31)
        return all_tables

# %% [markdown]
# ### Extract the commune names from each df

# %%
def find_first_occurrence(df, targets=["minimal", "minimum"]):
    """Find the row index of the first occurrence of target texts in a DataFrame."""
    
    for row_index, row in df.iterrows():
        for value in row:
            if isinstance(value, str) and any(target in value.lower() for target in targets):
                return row_index
    return None
    
def extract_commune_name_v21(df):
    """Revised function with adjusted logic for the new case."""
    
    name = str(df.iloc[0, 0])+str(df.iloc[0, 1])+str(df.iloc[1, 0]) + str(df.iloc[1, 1])
    # Remove the specified strings from the combined content
    for to_remove in ["Commune de", "Commune d'", "Communes d'","Nature de l’Immeuble", 
                      "Type d’Immeuble /(Caractéristiques)","Type d'Immeuble / (caractéristiques)",
                      'None',"Type d’Immeuble (Caractéristiques)","Nature de\nl’Immeuble","Commune",
                      "Type d’Immeuble(Caractéristiques)","Type d’Immeuble /(caracteristiq","s de",
                      "Type d’Immeuble /(Caractéristiq","Partie Ouest et Sud(2): Autres quartiers",'province',
                      'Type d’Immeuble (Caractéristiques)','NOUVELLE VILLE',"Type d’Immeuble / (Caractéristiques)",
                     "Type d’Immeuble(caracteristique )","commune de","commune","COMMUNE","(*)","(M'cil)","COMMUNE D",
                         "Type d’Immeuble (caracteristique )",'Partie "Est" (1) : Quartiers El-Barqui, Victor Hugo, Petit Lac, Bel Air, Saint-Eugène, Delmonte, Carteaux, Centre ville, Gambetta, Point du jour etFalaises.',
                             	]:
        name = name.replace(to_remove, '')
    name  = name.strip()
    
     
    if find_first_occurrence(df) == 3:
        return name, df
    else:
        df = df.drop(0).reset_index(drop=True)    
        return name, df

# %% [markdown]
# ## Apartments part

# %%
"""def clean_table_v5(df):
    #Enhanced function to clean and process the table with improved commune name extraction.
    name, df =  extract_commune_name_v21(df)
    try:
        # Step 1: Commune name is already provided
        
        # Step 2: Adjusting header, dropping unnecessary columns
        df_cleaned = df.iloc[4:, :].reset_index(drop=True)
        
        # Step 3: Assign new column names
        new_column_names = [
            "type_1", "type_2", "residential_min", "residential_madef" ]"""
        
def clean_table_v5(df):
    """Enhanced function to clean and process the table with improved commune name extraction."""
    name, df =  extract_commune_name_v21(df)
    try:
        # Step 1: Commune name is already provided
        
        # Step 2: Adjusting header, dropping unnecessary columns
        df_cleaned = df.iloc[4:, :].reset_index(drop=True)
        
        # Step 3: Assign new column names
        new_column_names = [
            "type_1", "type_2", "residential_min", "residential_max", 
            "centre_min", "centre_max", "peripherique_min", "px", 
            "centre_min", "centre_max", "peripherique_min", "peripherique_max","eloigner_min", "eloigner_max"
        ]
        
        if len(df_cleaned.columns) != len(new_column_names):
            print(f"Warning: Skipping table {name} due to unexpected column count.")
            return None

        df_cleaned.columns = new_column_names
        
        # Step 4: Further cleaning
        df_cleaned['type_2'].iloc[3] = 'terrain_2_facade'
        df_cleaned['type_2'].iloc[4] = 'terrain_1_facade'
        
        # Step 5: Numeric Conversion
        numeric_columns = [
            "residential_min", "residential_max", 
            "centre_min", "centre_max", 
            "peripherique_min", "peripherique_max",
            "eloigner_min", "eloigner_max"
        ]
        
        for col in numeric_columns:
            df_cleaned[col] = df_cleaned[col].apply(
                    lambda x: float(x.replace(" ", "").replace("*", "").replace("-", "nan").replace("#REF!", "nan").replace('esavecraccordements','nan').replace('le','nan').replace('cordement','nan').replace('690\n552\n414\n276\n221\n124\n109', '690').replace('avecracnans', 'nan').replace('essansracnans', 'nan').replace('sansracnans', 'nan').replace("nts", "").replace("s", "").replace("t", "")) if isinstance(x, str) and x.strip() not in ["", "/"] else None
            )
        
        # Step 6: Filtering Rows
        df_cleaned = df_cleaned.iloc[[2, 13, 14,15,16,17,18], :]
        
        # Step 7: Setting 'type_2' as the index
        df_cleaned.set_index('type_2', inplace=True)

        # rename the indexies 
        new_index_names = ['Economique', 'Trerrain_2', 'Trerrain_1',]
        df_cleaned.index = new_index_names

        return name, df_cleaned
        
    except Exception as e:
        print(f'There is an error: {e}')
        return None

# %%
import pandas as pd
from pdfminer.pdfparser import PDFSyntaxError

pdfs_path = 'pdf/'   # put the location of the pdf's

all_data =  []

# get  the names of all the pdfs in dict format 
pdfs_in_folder = extract_names_from_pdfs(pdfs_path)

print(pdfs_in_folder)

for key, value in pdfs_in_folder.items():

    print(key)
    # READ THE PDFS 
    try:
        dfs = extract_tables_from_pdf(pdfs_path+value)
    except PDFSyntaxError:
        print(f"Warning: The file {value} seems to be an invalid PDF. Skipping...")
        continue
    
    #dfs = extract_tables_from_pdf(pdfs_path+value)

    # Create a list of cleaned dataframes with their respective names
    cleaned_dfs = [clean_table_v5(d) for d in dfs]
    

    for i, commune in enumerate(cleaned_dfs):
        try:
            # center
            centre_min  =commune[1].loc['Economique', 'centre_min'] 
            centre_max = commune[1].loc['Economique', 'centre_max']

                # perepheric
            peripherique_min  =commune[1].loc['Economique', 'peripherique_min'] 
            peripherique_max = commune[1].loc['Economique', 'peripherique_max']

                # calculate the mean_eloigner
            eloigner_min  =commune[1].loc['Economique', 'eloigner_min'] 
            eloigner_max = commune[1].loc['Economique', 'eloigner_max']

            

            all_data.append({
                    'stt_name': key,
                    'commune_name': commune[0],
                    'centre_min': centre_min,
                    'centre_max': centre_max,
                    'peripherique_min': peripherique_min,  # This will be either 'village' or 'city'
                    'peripherique_max': peripherique_max,
                    'far_min':eloigner_min,
                    'far_max':eloigner_max
                                })
        except Exception as e:
            print(f'The error is wilaya {key}, commune {i}')

# Display the first few entries in all_data_revised
impo_df = pd.DataFrame(all_data)
# Out:
# {'ouargla': 'OUARGLA_TRAN_23.pdf', 'ain_defla': 'AIN_DEFLA_TRAN_23.pdf', 'saida': 'SAIDA_TRAN_23.pdf', 'ouled_djellal': 'OULED_DJELLAL_TRAN_23.pdf', 'timimoun': 'TIMIMOUN_TRAN_23.pdf', 'elbayadh': 'ELBAYADH_TRAN_23.pdf', 'adrar': 'ADRAR_TRAN_23.pdf', 'souk_ahras': 'SOUK_AHRAS_TRAN_23.pdf', 'elmeniaa': 'ELMENIAA_TRAN_23.pdf', 'blida': 'BLIDA_TRAN_23.pdf', 'alger': 'ALGER_TRAN_23.pdf', 'djelfa': 'DJELFA_TRAN_23.pdf', 'mila': 'MILA_TRAN_23.pdf', 'touggourt': 'TOUGGOURT_TRAN_23.pdf', 'laghouat': 'LAGHOUAT_TRAN_23.pdf', 'boumerdes': 'BOUMERDES_TRAN_23.pdf', 'ghardaia': 'GHARDAIA_TRAN_23.pdf', 'djanet': 'DJANET_TRAN_23.pdf', 'jijel': 'JIJEL_TRAN_23.pdf', 'tipaza': 'TIPAZA_TRAN_23.pdf', 'annaba': 'ANNABA_TRAN_23.pdf', 'bouira': 'BOUIRA_TRAN_23.pdf', 'oum_elbouaghi': 'OUM_ELBOUAGHI_TRAN_23.pdf', 'eltarf': 'ELTARF_TRAN_23.pdf', 'khenchela': 'KHENCHELA_TRAN_23.pdf', 'naama': 'NAAMA_TRAN_23.pdf', 'relizane': 'RELIZANE_TRAN_23.pdf', 'tindouf': 'TINDOUF_TRAN_23.pdf', 'tissemsilt': 'TISSEMSILT_TRAN_23.pdf', 'tamenghasset': 'TAMENGHASSET_TRAN_23.pdf', 'timouchent': 'TIMOUCHENT_TRAN_23.pdf', 'bbmokhtar': 'BBMOKHTAR_TRAN_23.pdf', 'mostaganem': 'MOSTAGANEM_TRAN_23.pdf', 'bejaia': 'BEJAIA_TRAN_23.pdf', 'tebessa': 'TEBESSA_TRAN_23.pdf', 'sidi_bel_abbes': 'SIDI_BEL_ABBES_TRAN_23.pdf', 'eloued': 'ELOUED_TRAN_23.pdf', 'tiaret': 'TIARET_TRAN_23.pdf', 'insaleh': 'INSALEH_TRAN_23.pdf', 'bba': 'BBA_TRAN_23.pdf', 'skikda': 'SKIKDA_TRAN_23.pdf', 'setif': 'SETIF_TRAN_23.pdf', 'biskra': 'BISKRA_TRAN_23.pdf', 'msila': 'MSILA_TRAN_23.pdf', 'bechar': 'BECHAR_TRAN_23.pdf', 'tizi_ouzou': 'TIZI_OUZOU_TRAN_23.pdf', 'constantine': 'CONSTANTINE_TRAN_23.pdf', 'illizi': 'ILLIZI_TRAN_23.pdf', 'beni_abbes': 'BENI_ABBES_TRAN_23.pdf', 'mascara': 'MASCARA_TRAN_23.pdf', 'batna': 'BATNA_TRAN_23.pdf', 'guelma': 'GUELMA_TRAN_23.pdf', 'medea': 'MEDEA_TRAN_23.pdf', 'telemcen': 'TELEMCEN_TRAN_23.pdf', 'elmeghaier': 'ELMEGHAIER_TRAN_23.pdf', 'inguezzam': 'INGUEZZAM_TRAN_23.pdf', 'chlef': 'CHLEF_TRAN_23.pdf', 'oran': 'ORAN_TRAN_23.pdf'}
# ouargla
# Warning: Skipping table Ouargla due to unexpected column count.
# Warning: Skipping table Rouissat due to unexpected column count.
# Warning: Skipping table Ain Baida due to unexpected column count.
# Warning: Skipping table Sidi Khuiled due to unexpected column count.
# Warning: Skipping table Hassi Ben Abdellah due to unexpected column count.
# Warning: Skipping table N'Goussa due to unexpected column count.
# Warning: Skipping table Hassi Messaoud due to unexpected column count.
# Warning: Skipping table Bourma due to unexpected column count.
# The error is wilaya ouargla, commune 0
# The error is wilaya ouargla, commune 1
# The error is wilaya ouargla, commune 2
# The error is wilaya ouargla, commune 3
# The error is wilaya ouargla, commune 4
# The error is wilaya ouargla, commune 5
# The error is wilaya ouargla, commune 6
# The error is wilaya ouargla, commune 7
# ain_defla
# Warning: Skipping table AIN DEFLA due to unexpected column count.
# Warning: Skipping table KHEMIS MILIANA due to unexpected column count.
# Warning: Skipping table SIDI LAKHDAR due to unexpected column count.
# Warning: Skipping table EL ATTAF due to unexpected column count.
# Warning: Skipping table ROUINA due to unexpected column count.
# Warning: Skipping table MILIANA due to unexpected column count.
# Warning: Skipping table BOUMEDFAA due to unexpected column count.
# Warning: Skipping table DJENDEL due to unexpected column count.
# Warning: Skipping table EL ABADIA due to unexpected column count.
# Warning: Skipping table BOURACHED due to unexpected column count.
# Warning: Skipping table DJELIDA due to unexpected column count.
# Warning: Skipping table EL AMRA due to unexpected column count.
# Warning: Skipping table HAMMAM RIGHA due to unexpected column count.
# Warning: Skipping table BIR OUELD KHELIFA due to unexpected column count.
# Warning: Skipping table ARIB due to unexpected column count.
# Warning: Skipping table AIN SULTANE due to unexpected column count.
# Warning: Skipping table MEKHATRIA due to unexpected column count.
# Warning: Skipping table BERBOUCHE due to unexpected column count.
# Warning: Skipping table EL MAINE due to unexpected column count.
# Warning: Skipping table BELAAS due to unexpected column count.
# Warning: Skipping table BATHIA due to unexpected column count.
# Warning: Skipping table EL HASSANIA due to unexpected column count.
# Warning: Skipping table AIN BOUYAHIA due to unexpected column count.
# Warning: Skipping table OUED DJEMAA due to unexpected column count.
# Warning: Skipping table TARIK IBN ZIAD due to unexpected column count.
# Warning: Skipping table AIN BENIANE due to unexpected column count.
# Warning: Skipping table DJEMAA OULED CHEIKH due to unexpected column count.
# Warning: Skipping table BEN ALLAL due to unexpected column count.
# Warning: Skipping table AIN TORKI due to unexpected column count.
# Warning: Skipping table TACHETA due to unexpected column count.
# Warning: Skipping table BORDJ EMIR KHALED due to unexpected column count.
# Warning: Skipping table EL HOUCAINIA due to unexpected column count.
# Warning: Skipping table ZEDDINE due to unexpected column count.
# Warning: Skipping table TIBERKANINE due to unexpected column count.
# Warning: Skipping table OUED CHORFA due to unexpected column count.
# Warning: Skipping table AIN LECHIAKH due to unexpected column count.
# The error is wilaya ain_defla, commune 0
# The error is wilaya ain_defla, commune 1
# The error is wilaya ain_defla, commune 2
# The error is wilaya ain_defla, commune 3
# The error is wilaya ain_defla, commune 4
# The error is wilaya ain_defla, commune 5
# The error is wilaya ain_defla, commune 6
# The error is wilaya ain_defla, commune 7
# The error is wilaya ain_defla, commune 8
# The error is wilaya ain_defla, commune 9
# The error is wilaya ain_defla, commune 10
# The error is wilaya ain_defla, commune 11
# The error is wilaya ain_defla, commune 12
# The error is wilaya ain_defla, commune 13
# The error is wilaya ain_defla, commune 14
# The error is wilaya ain_defla, commune 15
# The error is wilaya ain_defla, commune 16
# The error is wilaya ain_defla, commune 17
# The error is wilaya ain_defla, commune 18
# The error is wilaya ain_defla, commune 19
# The error is wilaya ain_defla, commune 20
# The error is wilaya ain_defla, commune 21
# The error is wilaya ain_defla, commune 22
# The error is wilaya ain_defla, commune 23
# The error is wilaya ain_defla, commune 24
# The error is wilaya ain_defla, commune 25
# The error is wilaya ain_defla, commune 26
# The error is wilaya ain_defla, commune 27
# The error is wilaya ain_defla, commune 28
# The error is wilaya ain_defla, commune 29
# The error is wilaya ain_defla, commune 30
# The error is wilaya ain_defla, commune 31
# The error is wilaya ain_defla, commune 32
# The error is wilaya ain_defla, commune 33
# The error is wilaya ain_defla, commune 34
# The error is wilaya ain_defla, commune 35
# saida
# Warning: Skipping table Saida due to unexpected column count.
# Warning: Skipping table Ain el hedjar due to unexpected column count.
# Warning: Skipping table Sidi Ahmed due to unexpected column count.
# Warning: Skipping table Moulay Larbi due to unexpected column count.
# Warning: Skipping table Doui Thabet due to unexpected column count.
# Warning: Skipping table Sidi Boubekeur due to unexpected column count.
# Warning: Skipping table Sidi Amar due to unexpected column count.
# Warning: Skipping table Hounet due to unexpected column count.
# Warning: Skipping table Ouled Khaled due to unexpected column count.
# Warning: Skipping table Hassasna due to unexpected column count.
# Warning: Skipping table Maamora due to unexpected column count.
# Warning: Skipping table Ain Sekhouna due to unexpected column count.
# Warning: Skipping table Ain Soltane due to unexpected column count.
# Warning: Skipping table Ouled Brahim due to unexpected column count.
# Warning: Skipping table Tircine due to unexpected column count.
# Warning: Skipping table Youb due to unexpected column count.
# The error is wilaya saida, commune 0
# The error is wilaya saida, commune 1
# The error is wilaya saida, commune 2
# The error is wilaya saida, commune 3
# The error is wilaya saida, commune 4
# The error is wilaya saida, commune 5
# The error is wilaya saida, commune 6
# The error is wilaya saida, commune 7
# The error is wilaya saida, commune 8
# The error is wilaya saida, commune 9
# The error is wilaya saida, commune 10
# The error is wilaya saida, commune 11
# The error is wilaya saida, commune 12
# The error is wilaya saida, commune 13
# The error is wilaya saida, commune 14
# The error is wilaya saida, commune 15
# ouled_djellal
# Warning: Skipping table Ouled Djellal due to unexpected column count.
# Warning: Skipping table Sidi Khaled due to unexpected column count.
# Warning: Skipping table Besbes due to unexpected column count.
# Warning: Skipping table Chaiba due to unexpected column count.
# Warning: Skipping table Ras Elmiaad due to unexpected column count.
# Warning: Skipping table Doucen due to unexpected column count.
# The error is wilaya ouled_djellal, commune 0
# The error is wilaya ouled_djellal, commune 1
# The error is wilaya ouled_djellal, commune 2
# The error is wilaya ouled_djellal, commune 3
# The error is wilaya ouled_djellal, commune 4
# The error is wilaya ouled_djellal, commune 5
# timimoun
# Warning: Skipping table TIMIMOUN due to unexpected column count.
# Warning: Skipping table KSAR KADDOUR due to unexpected column count.
# Warning: Skipping table OULED SAID due to unexpected column count.
# Warning: Skipping table DELDOUL due to unexpected column count.
# Warning: Skipping table METARFA due to unexpected column count.
# Warning: Skipping table TALMINE due to unexpected column count.
# Warning: Skipping table OULED AISSA due to unexpected column count.
# Warning: Skipping table Aougrout due to unexpected column count.
# Warning: Skipping table C Charouine due to unexpected column count.
# Warning: Skipping table Tinerkouk due to unexpected column count.
# The error is wilaya timimoun, commune 0
# The error is wilaya timimoun, commune 1
# The error is wilaya timimoun, commune 2
# The error is wilaya timimoun, commune 3
# The error is wilaya timimoun, commune 4
# The error is wilaya timimoun, commune 5
# The error is wilaya timimoun, commune 6
# The error is wilaya timimoun, commune 7
# The error is wilaya timimoun, commune 8
# The error is wilaya timimoun, commune 9
# elbayadh
# Warning: Skipping table El BAYADH due to unexpected column count.
# Warning: Skipping table BOUGTOUB due to unexpected column count.
# Warning: Skipping table EL ABIODH SIDI CHEIKH due to unexpected column count.
# Warning: Skipping table BOUALEM due to unexpected column count.
# Warning: Skipping table BREZINA due to unexpected column count.
# Warning: Skipping table GHASSOUL due to unexpected column count.
# Warning: Skipping table EL KHEITHER due to unexpected column count.
# Warning: Skipping table KEF EL AHMAR due to unexpected column count.
# Warning: Skipping table ARBAOUAT due to unexpected column count.
# Warning: Skipping table SIDI SLIMANE due to unexpected column count.
# Warning: Skipping table SIDI TIFOUR due to unexpected column count.
# Warning: Skipping table STITTEN due to unexpected column count.
# Warning: Skipping table TOUSMOULINE due to unexpected column count.
# Warning: Skipping table ROGASSA due to unexpected column count.
# Warning: Skipping table CHEGUIG due to unexpected column count.
# Warning: Skipping table KRAKDA due to unexpected column count.
# Warning: Skipping table SIDI AMEUR due to unexpected column count.
# Warning: Skipping table EL BNOUD due to unexpected column count.
# Warning: Skipping table EL MEHARA due to unexpected column count.
# Warning: Skipping table AIN EL ORAK due to unexpected column count.
# Warning: Skipping table BOUSSEMGHOUN due to unexpected column count.
# Warning: Skipping table CHELLALA due to unexpected column count.
# The error is wilaya elbayadh, commune 0
# The error is wilaya elbayadh, commune 1
# The error is wilaya elbayadh, commune 2
# The error is wilaya elbayadh, commune 3
# The error is wilaya elbayadh, commune 4
# The error is wilaya elbayadh, commune 5
# The error is wilaya elbayadh, commune 6
# The error is wilaya elbayadh, commune 7
# The error is wilaya elbayadh, commune 8
# The error is wilaya elbayadh, commune 9
# The error is wilaya elbayadh, commune 10
# The error is wilaya elbayadh, commune 11
# The error is wilaya elbayadh, commune 12
# The error is wilaya elbayadh, commune 13
# The error is wilaya elbayadh, commune 14
# The error is wilaya elbayadh, commune 15
# The error is wilaya elbayadh, commune 16
# The error is wilaya elbayadh, commune 17
# The error is wilaya elbayadh, commune 18
# The error is wilaya elbayadh, commune 19
# The error is wilaya elbayadh, commune 20
# The error is wilaya elbayadh, commune 21
# adrar
# Warning: Skipping table ADRAR due to unexpected column count.
# Warning: Skipping table TAMEST due to unexpected column count.
# Warning: Skipping table IN-ZEGHMIR due to unexpected column count.
# Warning: Skipping table TIT due to unexpected column count.
# Warning: Skipping table TIMOKTEN due to unexpected column count.
# Warning: Skipping table TAMENTIT due to unexpected column count.
# Warning: Skipping table SALI due to unexpected column count.
# Warning: Skipping table AKABLI due to unexpected column count.
# Warning: Skipping table OULED AHMED TIMMI due to unexpected column count.
# Warning: Skipping table BOUDA due to unexpected column count.
# Warning: Skipping table SEBAA due to unexpected column count.
# Warning: Skipping table Reggane due to unexpected column count.
# Warning: Skipping table ZaouietKounta due to unexpected column count.
# Warning: Skipping table Aoulef due to unexpected column count.
# Warning: Skipping table Fenoughil due to unexpected column count.
# Warning: Skipping table Tsabit due to unexpected column count.
# The error is wilaya adrar, commune 0
# The error is wilaya adrar, commune 1
# The error is wilaya adrar, commune 2
# The error is wilaya adrar, commune 3
# The error is wilaya adrar, commune 4
# The error is wilaya adrar, commune 5
# The error is wilaya adrar, commune 6
# The error is wilaya adrar, commune 7
# The error is wilaya adrar, commune 8
# The error is wilaya adrar, commune 9
# The error is wilaya adrar, commune 10
# The error is wilaya adrar, commune 11
# The error is wilaya adrar, commune 12
# The error is wilaya adrar, commune 13
# The error is wilaya adrar, commune 14
# The error is wilaya adrar, commune 15
# souk_ahras
# Warning: Skipping table Souk ahras due to unexpected column count.
# Warning: Skipping table Sedrata due to unexpected column count.
# Warning: Skipping table Taoura due to unexpected column count.
# Warning: Skipping table M'daourouch due to unexpected column count.
# Warning: Skipping table Merahna due to unexpected column count.
# Warning: Skipping table Bir Bou Haouch due to unexpected column count.
# Warning: Skipping table Heddada due to unexpected column count.
# Warning: Skipping table Oum El Adhaim due to unexpected column count.
# Warning: Skipping table Mechroha due to unexpected column count.
# Warning: Skipping table Oulad- Dris due to unexpected column count.
# Warning: Skipping table Tiffech due to unexpected column count.
# Warning: Skipping table Dréa due to unexpected column count.
# Warning: Skipping table Hennencha due to unexpected column count.
# Warning: Skipping table Khemissa due to unexpected column count.
# Warning: Skipping table Reggouba due to unexpected column count.
# Warning: Skipping table Zarouria due to unexpected column count.
# Warning: Skipping table Ouillen due to unexpected column count.
# Warning: Skipping table Terraguelt due to unexpected column count.
# Warning: Skipping table Zouabi due to unexpected column count.
# Warning: Skipping table Safel El Ouidene due to unexpected column count.
# Warning: Skipping table Khedara due to unexpected column count.
# Warning: Skipping table Ain Soltane due to unexpected column count.
# Warning: Skipping table Ain Zana due to unexpected column count.
# Warning: Skipping table Ouled Moumen due to unexpected column count.
# Warning: Skipping table Oued El Kebarit due to unexpected column count.
# Warning: Skipping table Sidi Fredj due to unexpected column count.
# The error is wilaya souk_ahras, commune 0
# The error is wilaya souk_ahras, commune 1
# The error is wilaya souk_ahras, commune 2
# The error is wilaya souk_ahras, commune 3
# The error is wilaya souk_ahras, commune 4
# The error is wilaya souk_ahras, commune 5
# The error is wilaya souk_ahras, commune 6
# The error is wilaya souk_ahras, commune 7
# The error is wilaya souk_ahras, commune 8
# The error is wilaya souk_ahras, commune 9
# The error is wilaya souk_ahras, commune 10
# The error is wilaya souk_ahras, commune 11
# The error is wilaya souk_ahras, commune 12
# The error is wilaya souk_ahras, commune 13
# The error is wilaya souk_ahras, commune 14
# The error is wilaya souk_ahras, commune 15
# The error is wilaya souk_ahras, commune 16
# The error is wilaya souk_ahras, commune 17
# The error is wilaya souk_ahras, commune 18
# The error is wilaya souk_ahras, commune 19
# The error is wilaya souk_ahras, commune 20
# The error is wilaya souk_ahras, commune 21
# The error is wilaya souk_ahras, commune 22
# The error is wilaya souk_ahras, commune 23
# The error is wilaya souk_ahras, commune 24
# The error is wilaya souk_ahras, commune 25
# elmeniaa
# Warning: Skipping table El Meniaa due to unexpected column count.
# Warning: Skipping table Hassi Gara due to unexpected column count.
# Warning: Skipping table HASSI LEFHEL due to unexpected column count.
# The error is wilaya elmeniaa, commune 0
# The error is wilaya elmeniaa, commune 1
# The error is wilaya elmeniaa, commune 2
# blida
# Warning: Skipping table BLIDA due to unexpected column count.
# Warning: Skipping table OULED YAICH due to unexpected column count.
# Warning: Skipping table BOUFARIK. due to unexpected column count.
# Warning: Skipping table : EL AFFROUN due to unexpected column count.
# Warning: Skipping table BOUGARA. due to unexpected column count.
# Warning: Skipping table MOUZAIA. due to unexpected column count.
# Warning: Skipping table OUED EL ALLEUG due to unexpected column count.
# Warning: Skipping table LARBAA due to unexpected column count.
# Warning: Skipping table MEFTAH due to unexpected column count.
# Warning: Skipping table BOUINAN due to unexpected column count.
# Warning: Skipping table CHEBLI due to unexpected column count.
# Warning: Skipping table BENI TAMOU due to unexpected column count.
# Warning: Skipping table CHIFFA due to unexpected column count.
# Warning: Skipping table SOUMAA due to unexpected column count.
# Warning: Skipping table BENI MERED. due to unexpected column count.
# Warning: Skipping table GUERROUAOU due to unexpected column count.
# Warning: Skipping table BENKHELLIL. due to unexpected column count.
# Warning: Skipping table OULED SLAMA due to unexpected column count.
# Warning: Skipping table AIN ROMANA due to unexpected column count.
# Warning: Skipping table OUED DJER due to unexpected column count.
# Warning: Skipping table BOUARFA due to unexpected column count.
# Warning: Skipping table HAMMAM MELOUANE due to unexpected column count.
# Warning: Skipping table SOUHANE due to unexpected column count.
# Warning: Skipping table DJEBABRA due to unexpected column count.
# Warning: Skipping table CHREA. due to unexpected column count.
# The error is wilaya blida, commune 0
# The error is wilaya blida, commune 1
# The error is wilaya blida, commune 2
# The error is wilaya blida, commune 3
# The error is wilaya blida, commune 4
# The error is wilaya blida, commune 5
# The error is wilaya blida, commune 6
# The error is wilaya blida, commune 7
# The error is wilaya blida, commune 8
# The error is wilaya blida, commune 9
# The error is wilaya blida, commune 10
# The error is wilaya blida, commune 11
# The error is wilaya blida, commune 12
# The error is wilaya blida, commune 13
# The error is wilaya blida, commune 14
# The error is wilaya blida, commune 15
# The error is wilaya blida, commune 16
# The error is wilaya blida, commune 17
# The error is wilaya blida, commune 18
# The error is wilaya blida, commune 19
# The error is wilaya blida, commune 20
# The error is wilaya blida, commune 21
# The error is wilaya blida, commune 22
# The error is wilaya blida, commune 23
# The error is wilaya blida, commune 24
# alger
# Warning: Skipping table Casbah due to unexpected column count.
# Warning: Skipping table Alger Centre due to unexpected column count.
# Warning: Skipping table Sidi M'hamed due to unexpected column count.
# Warning: Skipping table Belouizdad due to unexpected column count.
# Warning: Skipping table Hussein Dey due to unexpected column count.
# Warning: Skipping table Kouba due to unexpected column count.
# Warning: Skipping table Bourouba due to unexpected column count.
# Warning: Skipping table Bach Djerrah due to unexpected column count.
# Warning: Skipping table Magharia due to unexpected column count.
# Warning: Skipping table El Madania due to unexpected column count.
# Warning: Skipping table El Mouradia due to unexpected column count.
# Warning: Skipping table Hydra due to unexpected column count.
# Warning: Skipping table Gué de Constantine due to unexpected column count.
# Warning: Skipping table Bir Mourad Rais due to unexpected column count.
# Warning: Skipping table Birkhadem due to unexpected column count.
# Warning: Skipping table Sidi Moussa due to unexpected column count.
# Warning: Skipping table Dar El Beida due to unexpected column count.
# Warning: Skipping table Bab Ezzouar due to unexpected column count.
# Warning: Skipping table Mohamadia due to unexpected column count.
# Warning: Skipping table Bordj El Kiffan due to unexpected column count.
# Warning: Skipping table Ain Taya due to unexpected column count.
# Warning: Skipping table Bordj El Bahri due to unexpected column count.
# Warning: Skipping table El Marsa due to unexpected column count.
# Warning: Skipping table Rouiba due to unexpected column count.
# Warning: Skipping table Reghaia due to unexpected column count.
# Warning: Skipping table Heraoua due to unexpected column count.
# Warning: Skipping table El Harrach due to unexpected column count.
# Warning: Skipping table Oued Smar due to unexpected column count.
# Warning: Skipping table Baraki due to unexpected column count.
# Warning: Skipping table Eucalyptus due to unexpected column count.
# Warning: Skipping table Chéraga due to unexpected column count.
# Warning: Skipping table Ben Aknoune due to unexpected column count.
# Warning: Skipping table Staoueli due to unexpected column count.
# Warning: Skipping table Dely Ibrahim due to unexpected column count.
# Warning: Skipping table El Achour due to unexpected column count.
# Warning: Skipping table Draria due to unexpected column count.
# Warning: Skipping table Baba Hassen due to unexpected column count.
# Warning: Skipping table Ouled Fayet due to unexpected column count.
# Warning: Skipping table Ain Beniane due to unexpected column count.
# Warning: Skipping table Hammamat due to unexpected column count.
# Warning: Skipping table El Biar due to unexpected column count.
# Warning: Skipping table Bologhine due to unexpected column count.
# Warning: Skipping table Zéralda due to unexpected column count.
# Warning: Skipping table Douéra due to unexpected column count.
# Warning: Skipping table Shaoula due to unexpected column count.
# Warning: Skipping table Beni Messous due to unexpected column count.
# Warning: Skipping table Bouzaréah due to unexpected column count.
# Warning: Skipping table Souidania due to unexpected column count.
# Warning: Skipping table Kheraissia due to unexpected column count.
# Warning: Skipping table Bir Touta due to unexpected column count.
# Warning: Skipping table Mehalma due to unexpected column count.
# Warning: Skipping table Rahmania due to unexpected column count.
# Warning: Skipping table Tassala El Merdja due to unexpected column count.
# Warning: Skipping table Ouled Chebel due to unexpected column count.
# Warning: Skipping table Baba Ali due to unexpected column count.
# Warning: Skipping table Ramdania due to unexpected column count.
# Warning: Skipping table Sidi Menif due to unexpected column count.
# Warning: Skipping table Ouled Mendil due to unexpected column count.
# Warning: Skipping table Rais Hamidou due to unexpected column count.
# Warning: Skipping table Bab El Oued due to unexpected column count.
# Warning: Skipping table Oued Koriche due to unexpected column count.
# Warning: Skipping table Dekakna due to unexpected column count.
# The error is wilaya alger, commune 0
# The error is wilaya alger, commune 1
# The error is wilaya alger, commune 2
# The error is wilaya alger, commune 3
# The error is wilaya alger, commune 4
# The error is wilaya alger, commune 5
# The error is wilaya alger, commune 6
# The error is wilaya alger, commune 7
# The error is wilaya alger, commune 8
# The error is wilaya alger, commune 9
# The error is wilaya alger, commune 10
# The error is wilaya alger, commune 11
# The error is wilaya alger, commune 12
# The error is wilaya alger, commune 13
# The error is wilaya alger, commune 14
# The error is wilaya alger, commune 15
# The error is wilaya alger, commune 16
# The error is wilaya alger, commune 17
# The error is wilaya alger, commune 18
# The error is wilaya alger, commune 19
# The error is wilaya alger, commune 20
# The error is wilaya alger, commune 21
# The error is wilaya alger, commune 22
# The error is wilaya alger, commune 23
# The error is wilaya alger, commune 24
# The error is wilaya alger, commune 25
# The error is wilaya alger, commune 26
# The error is wilaya alger, commune 27
# The error is wilaya alger, commune 28
# The error is wilaya alger, commune 29
# The error is wilaya alger, commune 30
# The error is wilaya alger, commune 31
# The error is wilaya alger, commune 32
# The error is wilaya alger, commune 33
# The error is wilaya alger, commune 34
# The error is wilaya alger, commune 35
# The error is wilaya alger, commune 36
# The error is wilaya alger, commune 37
# The error is wilaya alger, commune 38
# The error is wilaya alger, commune 39
# The error is wilaya alger, commune 40
# The error is wilaya alger, commune 41
# The error is wilaya alger, commune 42
# The error is wilaya alger, commune 43
# The error is wilaya alger, commune 44
# The error is wilaya alger, commune 45
# The error is wilaya alger, commune 46
# The error is wilaya alger, commune 47
# The error is wilaya alger, commune 48
# The error is wilaya alger, commune 49
# The error is wilaya alger, commune 50
# The error is wilaya alger, commune 51
# The error is wilaya alger, commune 52
# The error is wilaya alger, commune 53
# The error is wilaya alger, commune 54
# The error is wilaya alger, commune 55
# The error is wilaya alger, commune 56
# The error is wilaya alger, commune 57
# The error is wilaya alger, commune 58
# The error is wilaya alger, commune 59
# The error is wilaya alger, commune 60
# The error is wilaya alger, commune 61
# djelfa
# Warning: Skipping table DJELFA due to unexpected column count.
# Warning: Skipping table AIN OUESSARA due to unexpected column count.
# Warning: Skipping table HASSI BAHBAH due to unexpected column count.
# Warning: Skipping table MESSAAD due to unexpected column count.
# Warning: Skipping table BIRINE due to unexpected column count.
# Warning: Skipping table FEIDH EL BOTMA due to unexpected column count.
# Warning: Skipping table CHAREF due to unexpected column count.
# Warning: Skipping table HAD SAHARY due to unexpected column count.
# Warning: Skipping table EL IDRISSIA due to unexpected column count.
# Warning: Skipping table DAR CHIOUKH due to unexpected column count.
# Warning: Skipping table AIN EL IBEL due to unexpected column count.
# Warning: Skipping table SIDI LADJEL due to unexpected column count.
# Warning: Skipping table EL KHEMIS due to unexpected column count.
# Warning: Skipping table HASSI FDOUL due to unexpected column count.
# Warning: Skipping table GUERNINI due to unexpected column count.
# Warning: Skipping table AIN MAABED due to unexpected column count.
# Warning: Skipping table HASSI EL EUCH due to unexpected column count.
# Warning: Skipping table ZAAFRANE due to unexpected column count.
# Warning: Skipping table MLILIHA due to unexpected column count.
# Warning: Skipping table SIDI BAIZID due to unexpected column count.
# Warning: Skipping table GUETTARA due to unexpected column count.
# Warning: Skipping table MOUDJEBARA A due to unexpected column count.
# Warning: Skipping table SELMANA due to unexpected column count.
# Warning: Skipping table SED RAHAL due to unexpected column count.
# Warning: Skipping table DELDOUL due to unexpected column count.
# Warning: Skipping table TADMIT due to unexpected column count.
# Warning: Skipping table ZACCAR due to unexpected column count.
# Warning: Skipping table AMOURA due to unexpected column count.
# Warning: Skipping table OUM EL ADAM due to unexpected column count.
# Warning: Skipping table BENHAR due to unexpected column count.
# Warning: Skipping table AIN FEKKA due to unexpected column count.
# Warning: Skipping table BOUIRA LAHDAB due to unexpected column count.
# Warning: Skipping table DOUIS due to unexpected column count.
# Warning: Skipping table AIN CHOUHADA due to unexpected column count.
# Warning: Skipping table EL GUEDDID due to unexpected column count.
# Warning: Skipping table BENI YAGOUB due to unexpected column count.
# The error is wilaya djelfa, commune 0
# The error is wilaya djelfa, commune 1
# The error is wilaya djelfa, commune 2
# The error is wilaya djelfa, commune 3
# The error is wilaya djelfa, commune 4
# The error is wilaya djelfa, commune 5
# The error is wilaya djelfa, commune 6
# The error is wilaya djelfa, commune 7
# The error is wilaya djelfa, commune 8
# The error is wilaya djelfa, commune 9
# The error is wilaya djelfa, commune 10
# The error is wilaya djelfa, commune 11
# The error is wilaya djelfa, commune 12
# The error is wilaya djelfa, commune 13
# The error is wilaya djelfa, commune 14
# The error is wilaya djelfa, commune 15
# The error is wilaya djelfa, commune 16
# The error is wilaya djelfa, commune 17
# The error is wilaya djelfa, commune 18
# The error is wilaya djelfa, commune 19
# The error is wilaya djelfa, commune 20
# The error is wilaya djelfa, commune 21
# The error is wilaya djelfa, commune 22
# The error is wilaya djelfa, commune 23
# The error is wilaya djelfa, commune 24
# The error is wilaya djelfa, commune 25
# The error is wilaya djelfa, commune 26
# The error is wilaya djelfa, commune 27
# The error is wilaya djelfa, commune 28
# The error is wilaya djelfa, commune 29
# The error is wilaya djelfa, commune 30
# The error is wilaya djelfa, commune 31
# The error is wilaya djelfa, commune 32
# The error is wilaya djelfa, commune 33
# The error is wilaya djelfa, commune 34
# The error is wilaya djelfa, commune 35
# mila
# Warning: Skipping table MILA due to unexpected column count.
# Warning: Skipping table SIDI KHELIFA due to unexpected column count.
# Warning: Skipping table AIN TIN due to unexpected column count.
# Warning: Skipping table FERDJIOUA due to unexpected column count.
# Warning: Skipping table YAHIA BENI GUECHA due to unexpected column count.
# Warning: Skipping table TADJENANET due to unexpected column count.
# Warning: Skipping table BEN YAHIA ABDERAHMENE due to unexpected column count.
# Warning: Skipping table OULED KHLOUF due to unexpected column count.
# Warning: Skipping table CHELGHOUM LAID due to unexpected column count.
# Warning: Skipping table TELEGHMA due to unexpected column count.
# Warning: Skipping table OUED SEGUEN due to unexpected column count.
# Warning: Skipping table M'CHIRA due to unexpected column count.
# Warning: Skipping table OUED ATHEMANIA due to unexpected column count.
# Warning: Skipping table AIN M'LOUK due to unexpected column count.
# Warning: Skipping table GRAREM GOUGA due to unexpected column count.
# Warning: Skipping table SIDI MEROUANE due to unexpected column count.
# Warning: Skipping table CHIGARA due to unexpected column count.
# Warning: Skipping table HAMALA due to unexpected column count.
# Warning: Skipping table OUED ENDJA due to unexpected column count.
# Warning: Skipping table ZEGHAIA due to unexpected column count.
# Warning: Skipping table TERAI BAINEN due to unexpected column count.
# Warning: Skipping table AMIRA ARRES due to unexpected column count.
# Warning: Skipping table TASSALA LEMTAI due to unexpected column count.
# Warning: Skipping table AHMED RACHEDI due to unexpected column count.
# Warning: Skipping table TIBERGUENT due to unexpected column count.
# Warning: Skipping table ROUACHED due to unexpected column count.
# Warning: Skipping table AIN BEIDA AHRICHE due to unexpected column count.
# Warning: Skipping table BOUHATEM due to unexpected column count.
# Warning: Skipping table TASSADANE HADDADA due to unexpected column count.
# Warning: Skipping table DERRADJI BOUSLAH due to unexpected column count.
# Warning: Skipping table MINAR ZARZA due to unexpected column count.
# Warning: Skipping table LAYADI BERBAS due to unexpected column count.
# The error is wilaya mila, commune 0
# The error is wilaya mila, commune 1
# The error is wilaya mila, commune 2
# The error is wilaya mila, commune 3
# The error is wilaya mila, commune 4
# The error is wilaya mila, commune 5
# The error is wilaya mila, commune 6
# The error is wilaya mila, commune 7
# The error is wilaya mila, commune 8
# The error is wilaya mila, commune 9
# The error is wilaya mila, commune 10
# The error is wilaya mila, commune 11
# The error is wilaya mila, commune 12
# The error is wilaya mila, commune 13
# The error is wilaya mila, commune 14
# The error is wilaya mila, commune 15
# The error is wilaya mila, commune 16
# The error is wilaya mila, commune 17
# The error is wilaya mila, commune 18
# The error is wilaya mila, commune 19
# The error is wilaya mila, commune 20
# The error is wilaya mila, commune 21
# The error is wilaya mila, commune 22
# The error is wilaya mila, commune 23
# The error is wilaya mila, commune 24
# The error is wilaya mila, commune 25
# The error is wilaya mila, commune 26
# The error is wilaya mila, commune 27
# The error is wilaya mila, commune 28
# The error is wilaya mila, commune 29
# The error is wilaya mila, commune 30
# The error is wilaya mila, commune 31
# touggourt
# Warning: Skipping table Touggourt due to unexpected column count.
# Warning: Skipping table Nezla due to unexpected column count.
# Warning: Skipping table Tebesbest due to unexpected column count.
# Warning: Skipping table Zaouia El Abidia due to unexpected column count.
# Warning: Skipping table Temacine due to unexpected column count.
# Warning: Skipping table Megarine due to unexpected column count.
# Warning: Skipping table El Hadjira due to unexpected column count.
# Warning: Skipping table Taibet due to unexpected column count.
# Warning: Skipping table M'Naguar due to unexpected column count.
# Warning: Skipping table Sidi Slimane due to unexpected column count.
# Warning: Skipping table Benaceur due to unexpected column count.
# Warning: Skipping table El Allia due to unexpected column count.
# Warning: Skipping table Blidat Ameur due to unexpected column count.
# The error is wilaya touggourt, commune 0
# The error is wilaya touggourt, commune 1
# The error is wilaya touggourt, commune 2
# The error is wilaya touggourt, commune 3
# The error is wilaya touggourt, commune 4
# The error is wilaya touggourt, commune 5
# The error is wilaya touggourt, commune 6
# The error is wilaya touggourt, commune 7
# The error is wilaya touggourt, commune 8
# The error is wilaya touggourt, commune 9
# The error is wilaya touggourt, commune 10
# The error is wilaya touggourt, commune 11
# The error is wilaya touggourt, commune 12
# laghouat
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[15], line 18
#      16 # READ THE PDFS
#      17 try:
# ---> 18     dfs = extract_tables_from_pdf(pdfs_path+value)
#      19 except PDFSyntaxError:
#      20     print(f"Warning: The file {value} seems to be an invalid PDF. Skipping...")
#
# Cell In[12], line 17, in extract_tables_from_pdf(pdf_path)
#      15 all_tables = []
#      16 for page in pdf.pages:
# ---> 17     tables = page.extract_tables(table_settings)
#      18     for table in tables:
#      19         all_tables.append(table)
#
# File ~/Desktop/H/beytic/lib/python3.10/site-packages/pdfplumber/page.py:415, in Page.extract_tables(self, table_settings)
#     413 tset = TableSettings.resolve(table_settings)
#     414 tables = self.find_tables(tset)
# --> 415 return [table.extract(**(tset.text_settings or {})) for table in tables]
#
# File ~/Desktop/H/beytic/lib/python3.10/site-packages/pdfplumber/page.py:415, in <listcomp>(.0)
#     413 tset = TableSettings.resolve(table_settings)
#     414 tables = self.find_tables(tset)
# --> 415 return [table.extract(**(tset.text_settings or {})) for table in tables]
#
# File ~/Desktop/H/beytic/lib/python3.10/site-packages/pdfplumber/table.py:430, in Table.extract(self, **kwargs)
#     428         kwargs["layout_width"] = cell[2] - cell[0]
#     429         kwargs["layout_height"] = cell[3] - cell[1]
# --> 430     cell_text = utils.extract_text(cell_chars, **kwargs)
#     431 else:
#     432     cell_text = ""
#
# File ~/Desktop/H/beytic/lib/python3.10/site-packages/pdfplumber/utils/text.py:537, in extract_text(chars, **kwargs)
#     533 y_tolerance = kwargs.get("y_tolerance", DEFAULT_Y_TOLERANCE)
#     534 extractor = WordExtractor(
#     535     **{k: kwargs[k] for k in WORD_EXTRACTOR_KWARGS if k in kwargs}
#     536 )
# --> 537 words = extractor.extract_words(chars)
#     538 lines = cluster_objects(words, itemgetter("doctop"), y_tolerance)
#     539 return "\n".join(" ".join(word["text"] for word in line) for line in lines)
#
# File ~/Desktop/H/beytic/lib/python3.10/site-packages/pdfplumber/utils/text.py:497, in WordExtractor.extract_words(self, chars)
#     496 def extract_words(self, chars: T_obj_list) -> T_obj_list:
# --> 497     return list(word for word, word_chars in self.iter_extract_tuples(chars))
#
# File ~/Desktop/H/beytic/lib/python3.10/site-packages/pdfplumber/utils/text.py:497, in <genexpr>(.0)
#     496 def extract_words(self, chars: T_obj_list) -> T_obj_list:
# --> 497     return list(word for word, word_chars in self.iter_extract_tuples(chars))
#
# File ~/Desktop/H/beytic/lib/python3.10/site-packages/pdfplumber/utils/text.py:489, in WordExtractor.iter_extract_tuples(self, chars)
#     486 grouping_key = itemgetter("upright", *self.extra_attrs)
#     487 grouped_chars = itertools.groupby(ordered_chars, grouping_key)
# --> 489 for keyvals, char_group in grouped_chars:
#     490     for word_chars in self.iter_chars_to_words(char_group):
#     491         yield (self.merge_chars(word_chars), word_chars)
#
# File ~/Desktop/H/beytic/lib/python3.10/site-packages/pdfplumber/utils/text.py:466, in WordExtractor.iter_sort_chars(self, chars)
#     463 cluster_key = "doctop" if upright else "x0"
#     465 # Cluster by line
# --> 466 subclusters = cluster_objects(
#     467     upright_cluster, itemgetter(cluster_key), self.y_tolerance
#     468 )
#     470 for sc in subclusters:
#     471     # Sort within line
#     472     sort_key = "x0" if upright else "doctop"
#
# File ~/Desktop/H/beytic/lib/python3.10/site-packages/pdfplumber/utils/clustering.py:60, in cluster_objects(xs, key_fn, tolerance, preserve_order)
#      58     cluster_tuples = [(x, cluster_dict.get(key_fn(x))) for x in xs]
#      59 else:
# ---> 60     cluster_tuples = sorted(
#      61         ((x, cluster_dict.get(key_fn(x))) for x in xs), key=get_1
#      62     )
#      64 grouped = itertools.groupby(cluster_tuples, key=get_1)
#      66 return [list(map(get_0, v)) for k, v in grouped]
#
# File ~/Desktop/H/beytic/lib/python3.10/site-packages/pdfplumber/utils/clustering.py:61, in <genexpr>(.0)
#      58     cluster_tuples = [(x, cluster_dict.get(key_fn(x))) for x in xs]
#      59 else:
#      60     cluster_tuples = sorted(
# ---> 61         ((x, cluster_dict.get(key_fn(x))) for x in xs), key=get_1
#      62     )
#      64 grouped = itertools.groupby(cluster_tuples, key=get_1)
#      66 return [list(map(get_0, v)) for k, v in grouped]
#
# KeyboardInterrupt:

# %%
# add to vent apartement salle
impo_df = impo_df.append(pd.Series(["mostaganem", "Oued El Kheir",50000,57500,40000,46000,20000,23000], index=impo_df.columns), ignore_index=True)
impo_df = impo_df.append(pd.Series(["chlef", "chlef",25000,28750,20000,23000,16000,18400], index=impo_df.columns), ignore_index=True)
impo_df = impo_df.append(pd.Series(["jijel", "Sidi Maarouf",27600.0,32500.0,25500.0,30000.0,16000.0,19000.0], index=impo_df.columns), ignore_index=True)
impo_df = impo_df.append(pd.Series(["medea", "Berrouaghia",57520,66148,45210,52000,36900,42435], index=impo_df.columns), ignore_index=True)

# %%
# apply to rent apartments
impo_df.loc[impo_df['stt_name'] == 'mascara', ['centre_min', 'centre_max', 'peripherique_min', 'peripherique_max', 'far_min', 'far_max']] /= 10
impo_df.loc[impo_df['stt_name'] == 'tinduf', ['centre_min', 'centre_max', 'peripherique_min', 'peripherique_max', 'far_min', 'far_max']] /= 100
impo_df = impo_df.append(pd.Series(["tizi_ouzou", "Draa Ben Khedda",250,288,80,92,60,69], index=impo_df.columns), ignore_index=True)
impo_df = impo_df.append(pd.Series(["tissemsilt", "Sidi Abed",24,34,20,27,14,20], index=impo_df.columns), ignore_index=True)
impo_df = impo_df.append(pd.Series(["ain defla", "ROUINA",50,58,30,35,30,35], index=impo_df.columns), ignore_index=True)

# %% [markdown]
# ## For lands

# %%
new_index_names = ['Economique', 'Trerrain_2', 'Trerrain_1','Trerrain_2_sans_raccordements', 'Trerrain_1_sans_raccordements',""]

# %%
def clean_table_v5(df):
    """Enhanced function to clean and process the table with improved commune name extraction."""
    name, df =  extract_commune_name_v21(df)
    try:
        # Step 1: Commune name is already provided
        
        # Step 2: Adjusting header, dropping unnecessary columns
        df_cleaned = df.iloc[4:, :].reset_index(drop=True)
        
        # Step 3: Assign new column names
        new_column_names = [
            "type_1", "type_2", "residential_min", "residential_max", 
            "centre_min", "centre_max", "peripherique_min", "peripherique_max","eloigner_min", "eloigner_max"
        ]
        
        if len(df_cleaned.columns) != len(new_column_names):
            print(f"Warning: Skipping table {name} due to unexpected column count.")
            return None

        df_cleaned.columns = new_column_names
        
        # Step 4: Further cleaning
        df_cleaned['type_2'].iloc[3] = 'terrain_2_facade'
        df_cleaned['type_2'].iloc[4] = 'terrain_1_facade'
        
        # Step 5: Numeric Conversion
        numeric_columns = [
            "residential_min", "residential_max", 
            "centre_min", "centre_max", 
            "peripherique_min", "peripherique_max",
            "eloigner_min", "eloigner_max"
        ]
        
        for col in numeric_columns:
            df_cleaned[col] = df_cleaned[col].apply(
                    lambda x: float(x.replace(" ", "").replace("*", "").replace("-", "nan").replace("#REF!", "nan").replace('esavecraccordements','nan').replace('le','nan').replace('cordement','nan').replace('690\n552\n414\n276\n221\n124\n109', '690').replace('avecracnans', 'nan').replace('essansracnans', 'nan').replace('sansracnans', 'nan').replace("nts", "").replace("s", "").replace("t", "")) if isinstance(x, str) and x.strip() not in ["", "/"] else None
            )
        
        # Step 6: Filtering Rows
        df_cleaned = df_cleaned.iloc[[2, 13, 14,15,16,17,18], :]
        
        # Step 7: Setting 'type_2' as the index
        df_cleaned.set_index('type_2', inplace=True)

        # rename the indexies 
        new_index_names = ['Economique', 'Trerrain_2', 'Trerrain_1','Trerrain_2_sans_raccordements', 'Trerrain_1_sans_raccordements',"Indivision","Industriel"]
        df_cleaned.index = new_index_names

        # drop columns 
        df_cleaned.drop(columns=['type_1'], inplace = True)
        
        return name, df_cleaned
        
    except Exception as e:
        print(f'There is an error: {e}')
        return None

# %%
from pdfminer.pdfparser import PDFSyntaxError
import pandas as pd



pdfs_path = 'pdf/'

all_data = []

# Get the names of all the pdfs in dict format 
pdfs_in_folder = extract_names_from_pdfs(pdfs_path)

print(pdfs_in_folder)

for key, value in pdfs_in_folder.items():

    print(key)
    # Read the PDFs 
    try:
        dfs = extract_tables_from_pdf(pdfs_path + value)
    except PDFSyntaxError:
        print(f"Warning: The file {value} seems to be an invalid PDF. Skipping...")
        continue

    # Create a list of cleaned dataframes with their respective names
    cleaned_dfs = [clean_table_v5(d) for d in dfs]

    for commune in cleaned_dfs:
        try:
            # Calculate the means
            commune[1]['residential_mean'] = (commune[1]['residential_min'] + commune[1]['residential_max']) / 2
            commune[1]['centre_mean'] = (commune[1]['centre_min'] + commune[1]['centre_max']) / 2
            commune[1]['peripherique_mean'] = (commune[1]['peripherique_min'] + commune[1]['peripherique_max']) / 2
            commune[1]['eloigner_mean'] = (commune[1]['eloigner_min'] + commune[1]['eloigner_max']) / 2

            # Drop the original min and max columns
            commune[1].drop(['residential_min', 'residential_max', 'centre_min', 'centre_max', 
                             'peripherique_min', 'peripherique_max', 'eloigner_min', 'eloigner_max'], axis=1, inplace=True)
            
            # Calculate the ratio as per previous example
            trerrain_1_values = commune[1].loc['Trerrain_1', :]
            ratio = commune[1].div(trerrain_1_values)
            
            # Drop the rows "Economique" and "Trerrain_1" from ratio
            ratio.drop(['Economique', 'Trerrain_1'], inplace=True)
            
            # Flatten the ratio DataFrame and store in all_data
            for index in ratio.index:
                all_data.append({
                    'stt_name': key,
                    'commune_name': commune[0],
                    'type': index,
                    'residential_mean': ratio.loc[index, 'residential_mean'],
                    'centre_mean': ratio.loc[index, 'centre_mean'],
                    'peripherique_mean': ratio.loc[index, 'peripherique_mean'],
                    'eloigner_mean': ratio.loc[index, 'eloigner_mean']
                })
                
        except Exception as e:
            print(f'The error is in wilaya {key}, commune {commune[0]}: {e}')

# Creating a DataFrame from all_data
final_df = pd.DataFrame(all_data)
# Out:
# {'ouargla': 'OUARGLA_TRAN_23.pdf', 'ain_defla': 'AIN_DEFLA_TRAN_23.pdf', 'saida': 'SAIDA_TRAN_23.pdf', 'ouled_djellal': 'OULED_DJELLAL_TRAN_23.pdf', 'timimoun': 'TIMIMOUN_TRAN_23.pdf', 'elbayadh': 'ELBAYADH_TRAN_23.pdf', 'adrar': 'ADRAR_TRAN_23.pdf', 'souk_ahras': 'SOUK_AHRAS_TRAN_23.pdf', 'elmeniaa': 'ELMENIAA_TRAN_23.pdf', 'blida': 'BLIDA_TRAN_23.pdf', 'alger': 'ALGER_TRAN_23.pdf', 'djelfa': 'DJELFA_TRAN_23.pdf', 'mila': 'MILA_TRAN_23.pdf', 'touggourt': 'TOUGGOURT_TRAN_23.pdf', 'laghouat': 'LAGHOUAT_TRAN_23.pdf', 'boumerdes': 'BOUMERDES_TRAN_23.pdf', 'ghardaia': 'GHARDAIA_TRAN_23.pdf', 'djanet': 'DJANET_TRAN_23.pdf', 'jijel': 'JIJEL_TRAN_23.pdf', 'tipaza': 'TIPAZA_TRAN_23.pdf', 'annaba': 'ANNABA_TRAN_23.pdf', 'bouira': 'BOUIRA_TRAN_23.pdf', 'oum_elbouaghi': 'OUM_ELBOUAGHI_TRAN_23.pdf', 'eltarf': 'ELTARF_TRAN_23.pdf', 'khenchela': 'KHENCHELA_TRAN_23.pdf', 'naama': 'NAAMA_TRAN_23.pdf', 'relizane': 'RELIZANE_TRAN_23.pdf', 'tindouf': 'TINDOUF_TRAN_23.pdf', 'tissemsilt': 'TISSEMSILT_TRAN_23.pdf', 'tamenghasset': 'TAMENGHASSET_TRAN_23.pdf', 'timouchent': 'TIMOUCHENT_TRAN_23.pdf', 'bbmokhtar': 'BBMOKHTAR_TRAN_23.pdf', 'mostaganem': 'MOSTAGANEM_TRAN_23.pdf', 'bejaia': 'BEJAIA_TRAN_23.pdf', 'tebessa': 'TEBESSA_TRAN_23.pdf', 'sidi_bel_abbes': 'SIDI_BEL_ABBES_TRAN_23.pdf', 'eloued': 'ELOUED_TRAN_23.pdf', 'tiaret': 'TIARET_TRAN_23.pdf', 'insaleh': 'INSALEH_TRAN_23.pdf', 'bba': 'BBA_TRAN_23.pdf', 'skikda': 'SKIKDA_TRAN_23.pdf', 'setif': 'SETIF_TRAN_23.pdf', 'biskra': 'BISKRA_TRAN_23.pdf', 'msila': 'MSILA_TRAN_23.pdf', 'bechar': 'BECHAR_TRAN_23.pdf', 'tizi_ouzou': 'TIZI_OUZOU_TRAN_23.pdf', 'constantine': 'CONSTANTINE_TRAN_23.pdf', 'illizi': 'ILLIZI_TRAN_23.pdf', 'beni_abbes': 'BENI_ABBES_TRAN_23.pdf', 'mascara': 'MASCARA_TRAN_23.pdf', 'batna': 'BATNA_TRAN_23.pdf', 'guelma': 'GUELMA_TRAN_23.pdf', 'medea': 'MEDEA_TRAN_23.pdf', 'telemcen': 'TELEMCEN_TRAN_23.pdf', 'elmeghaier': 'ELMEGHAIER_TRAN_23.pdf', 'inguezzam': 'INGUEZZAM_TRAN_23.pdf', 'chlef': 'CHLEF_TRAN_23.pdf', 'oran': 'ORAN_TRAN_23.pdf'}
# ouargla
# ain_defla
# saida
# ouled_djellal
# timimoun
# elbayadh
# adrar
# souk_ahras
# elmeniaa
# blida
# alger
# djelfa
# mila
# touggourt
# laghouat
# boumerdes
# ghardaia
# djanet
# jijel
# tipaza
# annaba
# bouira
# oum_elbouaghi
# eltarf
# khenchela
# naama
# relizane
# tindouf
# tissemsilt
# tamenghasset
# timouchent
# bbmokhtar
# mostaganem
# bejaia
# tebessa
# sidi_bel_abbes
# eloued
# tiaret
# insaleh
# bba
# skikda
# setif
# biskra
# msila
# bechar
# tizi_ouzou
# constantine
# illizi
# beni_abbes
# mascara
# batna
# guelma
# medea
# telemcen
# elmeghaier
# inguezzam
# chlef
# oran

# %% [markdown]
# ### calculate the average of prices

# %%
final_df['avg_ratio'] = final_df[['centre_mean', 'peripherique_mean', 'eloigner_mean']].mean(axis=1)

# %%
# Function to remove outliers for each land type

def remove_outliers(df, column='avg_ratio'):
    # Empty DataFrame to store results
    df_no_outliers = pd.DataFrame()

    # Loop through each type
    for _, group in df.groupby('type'):
        # Compute Q1 (25th percentile) and Q3 (75th percentile) of the column
        Q1 = group[column].quantile(0.25)
        Q3 = group[column].quantile(0.75)
        IQR = Q3 - Q1

        # Filter out the outliers
        mask = group[column].between(Q1 - 1.5 * IQR, Q3 + 1.5 * IQR)
        df_no_outliers = pd.concat([df_no_outliers, group[mask]])

    return df_no_outliers

# Remove outliers from the dataset
land_ratio_no_outliers = remove_outliers(final_df)

# Display the first few rows of the dataframe without outliers
land_ratio_no_outliers.head()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Descriptive Statistics for each land type
descriptive_stats = land_ratio_no_outliers.groupby('type')['avg_ratio'].describe()

# Visual Analysis: Box Plot for each land type
plt.figure(figsize=(12, 8))
sns.boxplot(x='type', y='avg_ratio', data=land_ratio_no_outliers)
plt.xticks(rotation=45)
plt.title('Variation of Average Ratios for Each Land Type Across Communes')
plt.xlabel('Land Type')
plt.ylabel('Average Ratio')
plt.show()

descriptive_stats

# %%
land_ratio_no_outliers.groupby('type')['avg_ratio'].quantile(0.5).round(2)

# %% [markdown]
# ### names corrections for state, commune. for Lands, apartments

# %%
mask = (impo_df['commune_name']=='Unknown')|(impo_df['commune_name']=='Commune de')|(impo_df['commune_name']=="Type d’Immeuble /(Caractéristiques)")| (impo_df['commune_name'].str.len() < 3)

impo_df = impo_df[~mask]
impo_df['commune_name']=impo_df['commune_name'].str.replace(":","", case=False)
impo_df['commune_name']=impo_df['commune_name'].str.replace(".","", case=False)
impo_df['commune_name']=impo_df['commune_name'].str.replace("-","", case=False)
impo_df['commune_name']=impo_df['commune_name'].str.replace("\n","", case=False)

# Replace 'BBA' with 'YES' in the 'STT_NAME' column

impo_df['stt_name'] = impo_df['stt_name'].str.replace('bba', 'Bordj Bou Arreridj',case=False)
impo_df['stt_name'] = impo_df['stt_name'].str.replace('alger', 'algiers',case=False)
impo_df['stt_name'] = impo_df['stt_name'].str.replace('aindefla', 'ain defla',case=False)
impo_df['stt_name'] = impo_df['stt_name'].str.replace('tindouf', 'tinduf',case=False)
#impo_df['commune_name'] = impo_df['commune_name'].replace('Alger Centre', 'Central Algiers')
impo_df['commune_name']=impo_df['commune_name'].str.replace(":","", case=False)
impo_df['commune_name'] = impo_df['commune_name'].str.replace('Bologhine', 'Bulughin',case=False)
impo_df['commune_name'] = impo_df['commune_name'].str.replace('tindouf', 'tinduf',case=False)
impo_df['stt_name'] = impo_df['stt_name'].str.replace('_', ' ')
impo_df['commune_name']=impo_df['commune_name'].str.replace('commune',"", case=False)
impo_df['commune_name']=impo_df['commune_name'].str.replace("d’","", case=False)
impo_df['commune_name']=impo_df['commune_name'].str.replace("é","e", case=False)
impo_df['commune_name'] = impo_df['commune_name'].str.replace('è', 'e',case=False)
impo_df['stt_name'] = impo_df['stt_name'].str.replace('è', 'e',case=False)
impo_df['commune_name']= impo_df['commune_name'].str.replace('Gue de constantine',"Djasr Kasentina", case=False)
impo_df['commune_name']= impo_df['commune_name'].str.replace('Ain naadja',"Djasr Kasentina", case=False)
impo_df['commune_name']=  impo_df['commune_name'].str.replace("Oran Partie","oran", case=False)
impo_df['commune_name']=impo_df['commune_name'].str.replace('central algiers',"Alger centre", case=False)
# Convert far_min and far_max columns to a standard numeric format
#impo_df['far_min'] = impo_df['far_min'].str.replace(' ', '').astype(float)
#impo_df['far_max'] = impo_df['far_max'].str.replace(' ', '').astype(float)
impo_df['commune_name']= impo_df['commune_name'].str.replace('gué de constantine',"Djasr Kasentina", case=False)
impo_df['commune_name']= impo_df['commune_name'].str.replace('Ain naadja',"Djasr Kasentina", case=False)
impo_df['commune_name']=  impo_df['commune_name'].str.replace("Oran Partie","oran", case=False)
impo_df['commune_name']=impo_df['commune_name'].str.replace("djemaa","djemaa beni habibi", case=False)
impo_df['stt_name']=impo_df['stt_name'].str.replace("timouchent","ain temouchent", case=False)
impo_df['commune_name']=impo_df['commune_name'].str.replace("oulhaca","oulhaca el gheraba", case=False)
impo_df['commune_name']=impo_df['commune_name'].str.replace("khezaras","kheraza", case=False)
impo_df['stt_name']=impo_df['stt_name'].str.replace("bbmokhtar","Bordj Badji Mokhtar", case=False)
impo_df['commune_name'] = impo_df['commune_name'].str.replace('EL KENNAR', 'El Kennar Nouchfi',case=False)
impo_df['commune_name'] = impo_df['commune_name'].str.replace('BENYAHIA', 'Benyahia Abderrahmane',case=False)
impo_df['commune_name'] = impo_df['commune_name'].str.replace('è', 'e',case=False)
impo_df['stt_name'] = impo_df['stt_name'].str.replace('è', 'e',case=False)
impo_df['stt_name'] = impo_df['stt_name'].str.replace('Tamenghasset', 'Tamenrasset',case=False)
impo_df['commune_name'] = impo_df['commune_name'].str.replace('Tamenghasset', 'Tamanrasset',case=False)
impo_df['stt_name'] = impo_df['stt_name'].str.replace('inguezzam', 'In Guezzam',case=False)

impo_df.reset_index(drop=True,inplace=True)

# %% [markdown]
# # Read the geojson (wilaya, commune) and clean it (to get from 'https://osm-boundaries.com/Map')

# %%
import geopandas as gpd

# Read GeoJSON file
gdf = gpd.read_file('algeria.geojson')

# drop the rows where admin_level	== 6
gdf = gdf[(gdf.admin_level	== 4) |(gdf.admin_level	== 8)]
gdf.drop(columns=['boundary','local_name',	'name_en'], inplace=True)
gdf.reset_index(drop=True,inplace=True)

# drop the df to 2.  
df_admin_4 = gdf[gdf['admin_level'] == 4]
df_admin_8 = gdf[gdf['admin_level'] == 8]

# Function to extract the wilaya name for each row in df_admin_8
def get_wilaya_name(row):
    # Split the parents values and get the middle value (osm_id of wilaya)
    wilaya_osm_id = int(row['parents'].split(',')[1])
    
    # Find the name from df_admin_4 where osm_id matches the extracted osm_id
    wilaya_name = df_admin_4[df_admin_4['osm_id'] == wilaya_osm_id]['name'].iloc[0]
    
    return wilaya_name

# Apply the function to df_admin_8 to create the new 'wilaya' column
df_admin_8['wilaya'] = df_admin_8.apply(get_wilaya_name, axis=1)
df_admin_8 = df_admin_8[['wilaya','name','geometry']]

# drop the not used df
del df_admin_4
del gdf

# %% [markdown]
# ###  Get all the villages and communes in the states

# %%
ox.settings.overpass_settings = '[out:json][timeout:180]'
ox.settings.use_cache = True
# Revised code using the existing commune_geometry

all_data_revised = []

for _, row in df_admin_8.iterrows():
    # Extract stt_name, commune_name, and commune_geometry
    stt_name = row['wilaya']
    commune_name = row['name']
    commune_geometry = row['geometry']
    
    try:
        # Get places within the commune's boundary
        places = ox.features_from_polygon(commune_geometry, tags={'place': ['village', 'city']})
        
        for _, place_row in places.iterrows():
            place_name = place_row.get('name', 'Unknown')
            place_type = place_row.get('place', 'Unknown')
            place_point = place_row['geometry'].centroid
            all_data_revised.append({
                        'stt_name': stt_name,
                        'commune_name': commune_name,
                        'place_name': place_name,
                        'place_type': place_type,  # This will be either 'village' or 'city'
                        'latitude': place_point.y,
                        'longitude': place_point.x
                    })

    except Exception as e:
        print(f"Error processing commune {commune_name} in wilaya {stt_name}: {e}")
    
    time.sleep(2)

# Display the first few entries in all_data_revised
df_places = pd.DataFrame(all_data_revised)

# %% [markdown]
# ### Mergethe two df

# %%
# Assuming df1 and df2 are based on the previously loaded and processed dataframes

# Merging df1 and df2 on the specified columns to get the area_km2 value for each commune in df1
df1_merged = pd.merge(df_places, df_admin_8[['wilaya', 'name','geometry']], 
                      left_on=['stt_name', 'commune_name'], 
                      right_on=['wilaya', 'name'], 
                      how='left')

# Renaming the area_km2 column to commune_area
#df1_merged.rename(columns={'area_km2': 'commune_area'}, inplace=True)

# Dropping the redundant columns from the merge
df1_with_area = df1_merged.drop(columns=['wilaya', 'name'])

# Displaying the first few rows of the resultant dataframe
df1_with_area.head()

# %% [markdown]
# ### Getting the center of the commune that didnt has tags

# %%
import osmnx as ox

# OSMnx settings
#ox.config(use_cache=True, log_console=True, user_agent="my_geocode_app")

# Function to get latitude and longitude for a wilaya and commune combination
def get_lat_lon(row):
    try:
        location = ox.geocode(f"{row['name']}, {row['wilaya']}, Algeria")
        return location
    except:
        return (None, None)

# Assuming your dataframe is named df
df_admin_8['latitude_center'], df_admin_8['longitude_center'] = zip(*df_admin_8.apply(get_lat_lon, axis=1))

# %%
df_admin_8_copy =df_admin_8.copy()
df_admin_8_copy['place_name'] = df_admin_8_copy['name']
df_admin_8_copy['place_type'] = 'city'

# %%
# Reorganize the columns
df_admin_8_copy = df_admin_8_copy[['wilaya', 'name', 'place_name', 'place_type', 'latitude_center', 'longitude_center', 'geometry']]

# Rename the columns
df_admin_8_copy = df_admin_8_copy.rename(columns={
    'wilaya': 'stt_name',
    'name': 'commune_name',
    'latitude_center': 'latitude',
    'longitude_center': 'longitude',
    'area_km2': 'commune_area'
})

# Now 'df' contains the DataFrame with the desired column order and renamed columns

# concat the 2 df 
final_villages_df = pd.concat([df1_with_area,df_admin_8_copy],axis=0)

#drop the duplicated rows

final_villages_df.drop_duplicates(subset=['commune_name' ,'place_name']) 

final_villages_df.reset_index(drop=True, inplace=True)

final_villages_df

# %% [markdown]
# ### Creating new columns centre, perepheric

# %%
final_villages_df.reset_index(drop=True, inplace=True)

# %%
final_villages_df['commune_name'] = final_villages_df['commune_name'].str.replace("Al Muhammadiyya",'Mohammadia', case=False)
final_villages_df['commune_name'] = final_villages_df['commune_name'].str.replace("Qudayyil",'Gdyel', case=False)
final_villages_df['stt_name'] = final_villages_df['stt_name'].str.replace("Médéa",'Medea', case=False)
final_villages_df['stt_name'] = final_villages_df['stt_name'].str.replace("é","e", case=False)
final_villages_df['stt_name'] = final_villages_df['stt_name'].str.replace("è","e", case=False)
final_villages_df['stt_name'] = final_villages_df['stt_name'].str.replace("ï","i", case=False)
final_villages_df['commune_name'] = final_villages_df['commune_name'].str.replace("maalma",'mehalma', case=False)
final_villages_df['commune_name'] = final_villages_df['commune_name'].str.replace("é","e", case=False)
final_villages_df['commune_name'] = final_villages_df['commune_name'].str.replace("ï","i", case=False)
final_villages_df['commune_name'] = final_villages_df['commune_name'].str.replace('central algiers',"Alger centre", case=False)
final_villages_df['commune_name'] = final_villages_df['commune_name'].str.replace("ash shalif","chlef", case=False)
final_villages_df['commune_name'] = final_villages_df['commune_name'].str.replace("é","e", case=False)
final_villages_df['commune_name'] = final_villages_df['commune_name'].str.replace("è","e", case=False)
final_villages_df['commune_name'] = final_villages_df['commune_name'].str.replace("ï","i", case=False)
final_villages_df['commune_name'] = final_villages_df['commune_name'].str.replace("ash shalif","chlef", case=False)
final_villages_df['commune_name'] = final_villages_df['commune_name'].str.replace("bashar","bechar", case=False)
final_villages_df['stt_name'] = final_villages_df['stt_name'].str.replace("bashar","bechar", case=False)
final_villages_df['commune_name'] = final_villages_df['commune_name'].str.replace("tulqa","tolga", case=False)
final_villages_df['commune_name'] = final_villages_df['commune_name'].str.replace("burj al kifan","Bordj El Kiffan", case=False)
final_villages_df['commune_name'] = final_villages_df['commune_name'].str.replace("herraoua","Heraoua", case=False)
final_villages_df['commune_name'] = final_villages_df['commune_name'].str.replace("bab al wadi","Bab El Oued", case=False)
final_villages_df['commune_name'] = final_villages_df['commune_name'].str.replace("bachdjarah","Bachdjerrah", case=False)
final_villages_df['commune_name'] = final_villages_df['commune_name'].str.replace("aghbal ⴰⵖⴱⴰⵍ أغبال","aghbal", case=False)

# %%
# Convert the strings to shapely geometries (if you load it)
from shapely.wkt import loads

def convert_to_geometry(data):
    try:
        return loads(data)
    except:
        return data

# Convert the strings to shapely geometries
final_villages_df['geometry'] = final_villages_df['geometry'].apply(convert_to_geometry)

# %% [markdown]
# ## Create geometries cercales for center, perepherique, far

# %%
# Define the necessary functions as provided

def point_to_3857(point):
    """Convert a point from EPSG:4326 to EPSG:3857"""
    gseries = gpd.GeoSeries([point], crs="EPSG:4326")
    return gseries.to_crs(epsg=3857).iloc[0]

def create_center_geometry(row):
    # Convert latitude and longitude to a Point in EPSG:3857
    point = Point(row['longitude'], row['latitude'])
    point_in_meters = point_to_3857(point)
    
    # Create buffer based on place_type
    if row['place_type'] == 'city':
        return point_in_meters.buffer(500)
    elif row['place_type'] == 'village':
        return point_in_meters.buffer(200)

def create_peripherique_geometry(row):
    # Convert latitude and longitude to a Point in EPSG:3857
    point = Point(row['longitude'], row['latitude'])
    point_in_meters = point_to_3857(point)
    
    # Create buffer based on place_type
    if row['place_type'] == 'city':
        return point_in_meters.buffer(1000)
    elif row['place_type'] == 'village':
        return point_in_meters.buffer(400)

def intersect_with_geometry(row, column_name):
    """Intersect a given geometry column with the main geometry."""
    return row[column_name].intersection(row['geometry'])

def subtract_center_from_peripherique(row):
    """Subtract the center geometry from the peripherique geometry."""
    return row['peripherique'].difference(row['center'])

# Now apply the transformations to the dataframe

# Convert the DataFrame to a GeoDataFrame using the 'center' column
gdf_center = gpd.GeoDataFrame(final_villages_df, geometry='geometry')
gdf_center.crs = "EPSG:4326"
final_villages_df['geometry'] = gdf_center['geometry'].to_crs("EPSG:3857")

# Create center and peripherique geometries
final_villages_df['center'] = final_villages_df.apply(create_center_geometry, axis=1)
final_villages_df['peripherique'] = final_villages_df.apply(create_peripherique_geometry, axis=1)


### at this point ['center','peripherique'] are  in "EPSG:3857" and [geometry] is  "EPSG:4326". you should converand them to 'EPSG:4326'   ###


# Intersect the center and peripherique geometries with the main geometry
final_villages_df['center'] = final_villages_df.apply(lambda row: intersect_with_geometry(row, 'center'), axis=1)
final_villages_df['peripherique'] = final_villages_df.apply(lambda row: intersect_with_geometry(row, 'peripherique'), axis=1)

# Subtract the center geometry from the peripherique geometry
final_villages_df['peripherique'] = final_villages_df.apply(subtract_center_from_peripherique, axis=1)

# transform the columns back to  'EPSG:4326'

final_villages_df['geometry'] = gpd.GeoSeries(final_villages_df['geometry'], crs="EPSG:3857").to_crs(epsg=4326)
final_villages_df['center'] = gpd.GeoSeries(final_villages_df['center'], crs="EPSG:3857").to_crs(epsg=4326)
final_villages_df['peripherique'] = gpd.GeoSeries(final_villages_df['peripherique'], crs="EPSG:3857").to_crs(epsg=4326)
final_villages_df.head()

# %% [markdown]
# ### Merge impo_df with final_villages_df

# %%
from fuzzywuzzy import fuzz

# 1. Precompute the choices
choices = impo_df.apply(lambda x: (x['stt_name'] + " " + x['commune_name']).lower(), axis=1).tolist()

# 2. Vectorized function to get best matches using fuzz.ratio
def get_best_match_vectorized(combined_name):
    scores = [fuzz.ratio(combined_name, choice) for choice in choices]
    max_score_index = scores.index(max(scores))
    
    # If the score is above a certain threshold, return the index
    if scores[max_score_index] > 80:
        return max_score_index
    return None

# Applying the function to get best matches
combined_names_series = (final_villages_df['stt_name'] + " " + final_villages_df['commune_name']).str.lower()
final_villages_df['matched_index'] = combined_names_series.apply(get_best_match_vectorized)

# 3. Merge the two DataFrames on the new index
final_villages_df = pd.merge(final_villages_df, impo_df, left_on="matched_index", right_index=True, how="left", suffixes=('', '_y'))

# Keeping only the relevant columns and dropping duplicated columns
columns_to_keep = ['stt_name', 'commune_name', 'place_name', 'place_type', 'latitude', 'longitude', 'geometry', 'center', 'peripherique', 
                   'centre_min', 'centre_max', 'peripherique_min', 'peripherique_max', 'far_min', 'far_max']
final_villages_df = final_villages_df[columns_to_keep]

final_villages_df.head()

# %%
# Filter rows where stt_name is "algiers" and place_type is "city"
algiers_city_df = final_villages_df[(final_villages_df['stt_name'] == 'algiers') & (final_villages_df['place_type'] == 'city')]

# Keep all rows from other stt_name values without any filtering
other_stt_df = final_villages_df[final_villages_df['stt_name'] != 'algiers']

# Concatenate the two filtered dataframes
final_villages_df = pd.concat([algiers_city_df, other_stt_df])

# Drop the 'place_name' and 'place_type' columns
final_villages_df = final_villages_df.drop(columns=['place_name', 'place_type'])

# Identify repeated communes within the same stt_name
repeated_communes = final_villages_df.groupby(['stt_name', 'commune_name']).size().reset_index(name='counts')
repeated_communes = repeated_communes[repeated_communes['counts'] > 1]

# %% [markdown]
# ### Put all the geometries of the same state in one geometry

# %%
from shapely import wkt
from shapely.ops import unary_union

# Function to combine geometries
def combine_geometries(df, column_name):
    # Convert the WKT strings to shapely geometries
    geometries = df[column_name]
    
    # Clean and filter out invalid geometries
    cleaned_geometries = [geom.buffer(0) for geom in geometries if geom.is_valid]
    
    # Combine the geometries
    combined_geometry = unary_union(cleaned_geometries)
    return combined_geometry  # Return the shapely geometry

# Iterate over the repeated communes and combine their geometries
for _, row in repeated_communes.iterrows():
    mask = (final_villages_df['stt_name'] == row['stt_name']) & (final_villages_df['commune_name'] == row['commune_name'])
    subset = final_villages_df[mask]
    
    final_villages_df.loc[mask, 'center'] = combine_geometries(subset, 'center')
    final_villages_df.loc[mask, 'peripherique'] = combine_geometries(subset, 'peripherique')

# After combining, we can keep only the first row of the repeated communes and drop the rest
for _, row in repeated_communes.iterrows():
    mask = (final_villages_df['stt_name'] == row['stt_name']) & (final_villages_df['commune_name'] == row['commune_name'])
    indices_to_drop = final_villages_df[mask].index[1:]
    final_villages_df.drop(indices_to_drop, inplace=True)

final_villages_df.reset_index(drop=True, inplace=True)
final_villages_df
